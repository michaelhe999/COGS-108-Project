# %% [markdown]
# # A Majorly Important Choice
#
# # Video Link:
# insert link here owo
#
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [ X ] YES - make available
# * [  ] NO - keep private
#
# # Names
#
# - Michael He
# - Felicia Zhang
# - Dhiren Patel
# - Sarah Li
#
# # Abstract
#
# We decided to do an analysis of how the job market affects students when they decide what major to pursue in college as this topic is relevant to us as students who at least partially chose our majors based on future job prospects. We conducted this analysis by gathering data from the US Bureau of Labor statistics and the Common Data Set for a selected collection of schools, and comparing the proportions of students who were conferred degrees in certain major fields and jobs related to those major field through a paired t-test. Overall, we found that there is no correlation between the percentages of degrees conferred in a certain year to the job market trends of that year, or any year up to 6 years before. This means that job market trends cannot be used to predict student major decisions.

# %% [markdown]
# # Research Question

# %% [markdown]
# Do national and local job market trends (measured by the number of jobs across the nation and in certain metropolitan areas) influence the selection of majors among undergraduate students at UCSD and other selected universities across the nation? What is more influential, the national or local job market, and which years prior to graduation are most influential on major choice?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# It can easily be stated that people go to college in order to get a job after graduation. Since the major that students graduate with affect the industry they can work in after graduation, it seems like a natural assumption that the job market has some effect on what subject students choose to major in.
#
# Research has been done on similar topics; Baker et. al posits that community college graduates are about 1.5% more likely to choose a major that corresponds with a 1% increase in salary <a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1). Utilizing logit models to estimate the probabilities of different major selections and Ordinary Least Squares to model the relationship between major choice, employment security, and salary expectations, the paper concludes that community college students have less access to accurate job market information, and thus mostly consider course enjoyment, while barely considering employment probability.
#
# Similarly, Long et. al find that college majors are most strongly tied to salaries from 3 years before graduation (when most students have to choose their major) <a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2). Their analysis covered both national and state (Washington) wage and major trends, using regression models to estimate the association between major choice and wage rates from a few years ago. They also used Granger causality tests to measure if previous data on wages were predictive of major choice.
#
# Despite there being a lot of research tying the job market to student major choices, we found little research analyzing the effects of employment rates in various industry sectors on major choice. We also aim to analyze a wider range of factors, covering different university locations and university types (public vs. private). This is because we’ve seen some research show that location affects college education, but not necessarily the major distributions at those locations <a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3). While we have seen that the job market has significant influence on major choices, we aim to discover the timeframe between the job market and major effects, as well as if the local or national job market has more influence.
#
# 1. <a name="cite_note-1"></a> [1](#cite_ref-1) Baker, Rachel, et al. The Effect of Labor Market Information on Community College Students’ Major Choice, ScienceDirect, Aug. 2018, [edpolicy.umich.edu/sites/epi/files/uploads/02-2017-labor-market-major-choice.pdf](https://edpolicy.umich.edu/sites/epi/files/uploads/02-2017-labor-market-major-choice.pdf)
# 2. <a name="cite_note-2"></a> [2](#cite_ref-2) Long et. al Do Students’ College Major Choices Respond to Changes in Wages, Calder Center, January 2014, [https://caldercenter.org/sites/default/files/WP-107.pdf](https://caldercenter.org/sites/default/files/WP-107.pdf)
# 3. <a name="cite_note-3"></a> [3](#cite_ref-3) Higdon, Why does college location matter, April 2017, [https://www.northcentral.edu/blog/why-does-college-location-matter/](https://www.northcentral.edu/blog/why-does-college-location-matter/)

# %% [markdown]
# # Hypothesis

# %% [markdown]
# We predict that undergraduate major students are influenced by job market trends, with the strongest correlation between the majors students select and the job market conditions from approximately 4 years prior to when they first enter college. Specifically, we believe that national job market trends, such as wage growth and demand within central industries (e.g., healthcare, technology), will show a strong correlation with the selection of undergraduate majors across the United States. Furthermore, local job market trends, including employment opportunities and industry-specific demand will have a stronger influence on the major selection at universities such as UCSD, where students are more prone to aligning their academic focus with the region’s economic landscape.
#
# For this study, we would define major choice as the number of individuals who graduated with the major (or a similar one), and job market trends as the number of jobs in that field. Since our background research shows that factors such as wages affect major choice, it can be assumed that the increased possibility of finding a job in that field (which would lead to the receiving wages in the first place), would also be a factor in people’s major decision. We believe that these two variables would have a positive correlation — as the number of jobs in a certain field increases, so does the number of college students who choose a related major.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1
#   - Dataset Name: US Bureau of Labor Statistics Occupational Employment and Wage Estimates by Metropolitan and Nonmetropolitan Area (BLS OEWS for short)
#   - Link to the dataset: [BLS OEWS](https://www.bls.gov/oes/tables.htm)
#   - Cleaned dataset: [all_year_bls](dataset_work/bls_data/useful_csvs/all_years.csv)
#   - Number of observations: 74580
#   - Number of variables: 23
# - Dataset #2
#   - Dataset Name: School Common Data Set Degrees Conferred (CDS for short)
#   - Link to the dataset: [CDS](https://docs.google.com/spreadsheets/d/19kN52hyig4k--l1GXVEiIQVoSM10L_shYSVXepYsSDM/edit?usp=sharing)\
#   This is actually a link to a Google Sheet, where you can find the link to each school's CDS\
#   - Cleaned dataset: [all_year_csd](dataset_work/cds_data/useful_csvs/all_years.csv)
#   - Number of observations: 3092
#   - Number of variables: 7
#
# #### BLS OEWS:
# This dataset encompasses 2006-2023 employment data by metropolitan/non-metropolitan area. Our cleaned dataset has 8 areas, each of which were chosen because of their proximity to one of the schools we are analyzing. The important variables in the data set are year, location, occupation title (string), total employment (int), and average salary (int), although the other fields we left in the dataset also help with general analysis and classification. The employment count proportion and the salary may be proxies for overall desirability of the job.
#
# To clean this dataset, we had to download all the `.xls` and `.xlsx` files from the BLS, convert them to `.csv`s, and then pull only the relevant areas from each year's dataset. Then, to combine the datasets and standardize the columns, some columns were dropped or renamed, leading to the overall dataset.
#
# #### CDS:
# This dataset encompasses 8 US universities, which were chosen for reasons listed in our [Google Sheet](https://docs.google.com/spreadsheets/d/19kN52hyig4k--l1GXVEiIQVoSM10L_shYSVXepYsSDM/edit?usp=sharing). The most limiting university was Colgate University, with the first CDS being from 2014, so the years span from 2014 graduation to 2023 graduation degrees conferred. This gives us a good 10 year window to work with. The important variables in this dataset are year, college, Category (major), and Bachelor's (a percentage of the graduating class). The major percentages may be proxies for the overall desirability of the major.
#
# To clean this dataset, we had to download all the `.pdf` files of the CDS from each school. We then created and ran a pdf scraper to pull the Degrees Conferred table from each PDF; there were a few cases where this had to be done manually because of inconsistent formatting or lack of downloadable PDF. Then, to combine the datasets, equivalent columns were combined, leading to the overall dataset.
#
# ##### Combining
# To combine these datasets, it's necessary to line up majors at colleges with jobs. This means we will probably use a classifier to fit the jobs in 'OCC-TITLE' to the majors in 'Category'. Then, we can graph the relationships between employment rates and major trends.

# %% [markdown]
# ## BLS OEWS

# %%
# Import necessary libraries

import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Changes all xls files into csv files

def xls_x_to_csv(file_path, file_type):
    # Read the .xls file
    df = pd.read_excel(file_path)
    # Define the .csv file path
    csv_file_path = file_path.replace(file_type, '.csv')
    # Save the dataframe to a .csv file
    df.to_csv(csv_file_path, index=False)

def all_xls_x_to_csv(bls_data_path):
    # Iterate over each year folder in the bls_data folder
    for year_folder in os.listdir(bls_data_path):
        if year_folder == "full_processed_csvs" or year_folder == "useful_csvs":
            continue
        year_path = os.path.join(bls_data_path, year_folder)
        if os.path.isdir(year_path):
            # Iterate over each .xls file in the year folder
            for file in os.listdir(year_path):
                if file.endswith('.xls'):
                    file_path = os.path.join(year_path, file)
                    xls_x_to_csv(file_path, '.xls')
                if file.endswith('.xlsx'):
                    file_path = os.path.join(year_path, file)
                    xls_x_to_csv(file_path, '.xlsx')
                    
# Uncomment the line below to change all xls and xlsx files into csv files
# all_xls_x_to_csv('dataset_work/bls_data')

# %%
# Read through each year of csvs, and get only relevant areas into one csv
relevant_areas = ["Los Angeles-Long Beach-Santa Ana, CA", 
"Los Angeles-Long Beach-Anaheim, CA", # shifts classification in 2015
"Western New Hampshire nonmetropolitan area",
"Southwestern New Hampshire nonmetropolitan area",
"West Central New Hampshire nonmetropolitan area",
"Southwest New Hampshire nonmetropolitan area",
"West Central-Southwest New Hampshire nonmetropolitan area",
"San Diego-Carlsbad-San Marcos, CA",
"San Diego-Carlsbad, CA", # shifts classification in 2015
"Ann Arbor, MI",
"Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Division",
"Washington-Arlington-Alexandria, DC-VA-MD-WV", # shifts classification in 2018
"Spokane, WA",
"Spokane-Spokane Valley, WA", # shifts classification in 2015
"Winston-Salem, NC",
"Utica-Rome, NY",
]

# All the relevant New Hampshire areas:
# "Other New Hampshire nonmetropolitan area", - this means central - do not use
# "Western New Hampshire nonmetropolitan area", - use
# "Southwestern New Hampshire nonmetropolitan area", - use
# "West Central New Hampshire nonmetropolitan area", - use - 2015
# "Central New Hampshire nonmetropolitan area", - do not use - 2015
# "Southwest New Hampshire nonmetropolitan area", - use - 2015
# "West Central-Southwest New Hampshire nonmetropolitan area", - 2018 combination of west central and southwest - only choice aside from central in 2018 onwards
# overall, we'll use West Central-Southwest, while avoiding Central?

def process_year(bls_data_path, year_path, relevant_areas, column_name, year_number):
    # Create the output directory if it doesn't exist
    processed_folder = os.path.join(bls_data_path, "full_processed_csvs")
    os.makedirs(processed_folder, exist_ok=True)

    result_df = pd.DataFrame()

    # Iterate through all CSV files in the year folder
    for file in os.listdir(year_path):
        if file.endswith('.csv'):
            file_path = os.path.join(year_path, file)
            df = pd.read_csv(file_path)
            if column_name in df.columns:
                # Filter rows where the column value is in relevant_areas
                filtered_df = df[df[column_name].isin(relevant_areas)]
                result_df = pd.concat([result_df, filtered_df], ignore_index=True)

    # Define the output file path
    output_file_path = os.path.join(processed_folder, f"{year_number}_relevant.csv")

    # Write the filtered DataFrame to the output file
    result_df.to_csv(output_file_path, index=False)
    print(f"Processed data saved to {output_file_path}")

def process_all_years(bls_data_path, relevant_areas):
    # Iterate over each year folder in the bls_data folder
    for year_folder in os.listdir(bls_data_path):
        if year_folder == "full_processed_csvs" or year_folder == "useful_csvs":
            continue
        year_number = int(year_folder)
        year_path = os.path.join(bls_data_path, year_folder)
        column_name = ''
        if os.path.isdir(year_path):
             # AREA_NAME 2006-2018, area_title in 2019, AREA_TITLE onwards
            if year_number < 2019:
                column_name = 'AREA_NAME'
            elif year_number == 2019:
                column_name = 'area_title'
            elif year_number > 2019:
                column_name = 'AREA_TITLE'
            else:
                print("Error: invalid year")
                exit(1)
            process_year(bls_data_path, year_path, relevant_areas, column_name, year_number)

process_all_years('dataset_work/bls_data', relevant_areas)
# Out:
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2013_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2014_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2022_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2023_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2015_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2012_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2008_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2006_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2007_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2009_relevant.csv
# Processed data saved to dataset_work/bls_data/full_processed_csvs/2017_relevant.csv
# ...

# %%
# Format all area names and column names to be consistent, more cleaning done in next step

def format_area_names(df):
    if 'AREA_NAME' in df.columns:
        df.rename(columns={'AREA_NAME': 'AREA_TITLE'}, inplace=True)
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Los Angeles-Long Beach-Santa Ana, CA", "Los Angeles-Long Beach-Anaheim, CA")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("San Diego-Carlsbad-San Marcos, CA", "San Diego-Carlsbad, CA")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Spokane, WA", "Spokane-Spokane Valley, WA")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Western New Hampshire nonmetropolitan area", "West Central-Southwest New Hampshire nonmetropolitan area")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Southwestern New Hampshire nonmetropolitan area", "West Central-Southwest New Hampshire nonmetropolitan area")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("West Central New Hampshire nonmetropolitan area", "West Central-Southwest New Hampshire nonmetropolitan area")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Southwest New Hampshire nonmetropolitan area", "West Central-Southwest New Hampshire nonmetropolitan area")
    df['AREA_TITLE'] = df['AREA_TITLE'].replace("Washington-Arlington-Alexandria, DC-VA-MD-WV", "Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Division")
    if 'GROUP' in df.columns:
        df.rename(columns={'GROUP': 'OCC_GROUP'}, inplace=True)
    elif 'O_GROUP' in df.columns:
        df.rename(columns={'O_GROUP': 'OCC_GROUP'}, inplace=True)
    if 'LOC QUOTIENT' in df.columns:
        df.rename(columns={'LOC QUOTIENT': 'LOC_QUOTIENT'}, inplace=True)
    if 'LOC_QUOTIENT' not in df.columns:
        df['LOC_QUOTIENT'] = pd.NA
    
    return df

def format_column_names(df):
    for column in df.columns:
        df.rename(columns={column: column.upper()}, inplace=True)
    return df

def format_year(file_path):
    df = pd.read_csv(file_path)
    df = format_column_names(df)
    df = format_area_names(df)
    df.to_csv(file_path, index=False)

def format_all_years(processed_csv_path):
    for file in os.listdir(processed_csv_path):
        if file.endswith('.csv'):
            file_path = os.path.join(processed_csv_path, file)
            format_year(file_path)

format_all_years('dataset_work/bls_data/full_processed_csvs')

# %%
# Finish cleaning data by dropping useless columns

def drop_useless_columns(df):
    # Drop columns that are not needed
    drop_list = ['AREA_TYPE', 'NAICS', 'NAICS_TITLE', 'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'PCT_TOTAL', 'PCT_RPT', 'PRIM_STATE', 'AREA']
    # OCC_CODE is the same as OCC_TITLE, PCT_TOTAL and PCT_RPT is always NaN, PRIM_STATE is in AREA_TITLE, AREA is same as AREA_TITLE, others cause issues
    for column in drop_list:
        if column in df.columns:
            df.drop(columns=[column], inplace=True)
    df.dropna(axis=1, how='all')
    return df

def drop_all_useless_columns(processed_csv_path):
    for file in os.listdir(processed_csv_path):
        if file.endswith('.csv'):
            file_path = os.path.join(processed_csv_path, file)
            df = pd.read_csv(file_path)
            out_df = drop_useless_columns(df)
            out_df.to_csv(os.path.join('dataset_work/bls_data/useful_csvs', file), index=False)

drop_all_useless_columns('dataset_work/bls_data/full_processed_csvs')

# %%
# Test to check if all years have the same columns and if all areas are represented

def test_csvs(useful_csv_path):
    reference_columns = None
    reference_area_titles = None
    for file in os.listdir(useful_csv_path):
        if file.endswith('.csv'):
            file_path = os.path.join(useful_csv_path, file)
            df = pd.read_csv(file_path)
            if reference_columns is None:
                reference_columns = set(df.columns)
            else:
                if set(df.columns) != reference_columns:
                    print(f"Warning: Columns in {file} do not match the reference columns.")
            if reference_area_titles is None:
                reference_area_titles = set(df['AREA_TITLE'].unique())
            else:
                if set(df['AREA_TITLE'].unique()) != reference_area_titles:
                    print(f"Warning: Areas in {file} do not match the reference areas.")
            unique_area_titles = df['AREA_TITLE'].nunique()
            if unique_area_titles != 8:
                print(f"Warning: {file} does not have all 8 areas represented.")

# %%
# Combine all years into one csv

def combine_years(useful_csv_path):
    combined_df = pd.DataFrame()
    for file in os.listdir(useful_csv_path):
        if file.endswith('.csv') and file != 'all_years.csv':
            file_path = os.path.join(useful_csv_path, file)
            df = pd.read_csv(file_path)
            year = int(file.split('_')[0])
            df['YEAR'] = year
            combined_df = pd.concat([combined_df, df], ignore_index=True)
    combined_df.dropna(axis=1, how='all')
    column_order = ['YEAR', 'AREA_TITLE', 'OCC_TITLE', 'OCC_GROUP', 'TOT_EMP', 'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 
    'H_PCT10', 'H_PCT25', 'H_MEDIAN', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY']
    combined_df = combined_df[column_order]
    combined_df = combined_df.sort_values(by=['YEAR', 'AREA_TITLE'], ascending=[True, True], kind='mergesort')
    combined_df.to_csv('dataset_work/bls_data/useful_csvs/all_years.csv', index=False)

combine_years('dataset_work/bls_data/useful_csvs')

# %%
df = pd.read_csv('dataset_work/bls_data/useful_csvs/all_years.csv')
print(f"DF shape: {df.shape}")
df.head()
# Out:
# DF shape: (87679, 23)
#    YEAR     AREA_TITLE                        OCC_TITLE OCC_GROUP TOT_EMP  \
# 0  2006  Ann Arbor, MI                  All Occupations       NaN  197810
# 1  2006  Ann Arbor, MI           Management occupations     major    8060
# 2  2006  Ann Arbor, MI                 Chief executives       NaN     540
# 3  2006  Ann Arbor, MI  General and operations managers       NaN    1670
# 4  2006  Ann Arbor, MI                      Legislators       NaN      30
#
#   EMP_PRSE JOBS_1000 LOC_QUOTIENT H_MEAN  A_MEAN  ... H_MEDIAN H_PCT75  \
# 0      1.5       NaN          NaN  22.29   46370  ...    18.26   27.99
# 1      3.7       NaN          NaN  45.54   94720  ...    41.80   56.95
# 2      9.6       NaN          NaN  76.39  158890  ...        #       #
# 3      6.1       NaN          NaN  46.89   97530  ...    41.20   59.33
# 4     27.0       NaN          NaN      *       *  ...        *       *
#
#   H_PCT90 A_PCT10 A_PCT25 A_MEDIAN A_PCT75 A_PCT90 ANNUAL HOURLY
# ...

# %% [markdown]
# ## CDS

# %%
# import libraries

import pdfplumber
import pandas as pd
import numpy as np
import os

# %%
# Pull degrees conferred tables from CDS PDFs

def extract_table_from_pdf(pdf_path, pdf_name, full_processed_csvs_folder):
    df_results = pd.DataFrame()
    print(f"Processing file {pdf_name}")
    with pdfplumber.open(pdf_path) as pdf:
        # Iterate over the pages in the PDF
        for page_num, page in enumerate(pdf.pages, start=1):
            # Extract text content from the page
            text = page.extract_text()
            # Check if "degrees conferred" exists in the page text (case insensitive)
            if "degrees conferred" in text.lower():
                print(f"Found 'degrees conferred' on page {page_num}. Extracting table...")
                tables = page.extract_tables()
                for table in tables:
                    df = pd.DataFrame(table[1:], columns=table[0])
                    df.columns = df.columns.str.replace('\n', ' ', regex=True)
                    df_results = pd.concat([df_results, df], ignore_index=True)
                special_cases = ["ucsd_2023", "wsu_2023"]
                extra_special_cases = ["caltech_2021", "caltech_2022", "caltech_2023", "asu_2021", "asu_2022", "asu_2023"]
                if pdf_name in special_cases : # handle special case where table is split across two pages on a case-by-case basis
                    next_page = pdf.pages[page_num]
                    next_tables = next_page.extract_tables()
                    if next_tables:
                        for table in next_tables:
                            df = pd.DataFrame(table[1:], columns=table[0])
                            top_row = df.columns
                            df.columns = df_results.columns
                            df.loc[-1] = top_row 
                            df.index = df.index + 1
                            df = df.sort_index()
                            df_results = pd.concat([df_results, df], ignore_index=True)
                if pdf_name in extra_special_cases : # handle special case where table is split across two pages and the column names are on the second page
                    next_page = pdf.pages[page_num]
                    next_tables = next_page.extract_tables()
                    if next_tables:
                        for table in next_tables:
                            df = pd.DataFrame(table[1:], columns=table[0])
                            df_results = pd.concat([df_results, df], ignore_index=True)
                break
        if df_results.empty:
            print(f"'degrees conferred' not found in page {page_num}.")

    if not df_results.empty:
        df_results = df_results.reset_index(drop=True)
        year_directory = os.path.join(full_processed_csvs_folder, pdf_name.split("_")[1])
        if not os.path.exists(year_directory):
            os.makedirs(year_directory)
        file_name = os.path.join(year_directory, f"{pdf_name}_degrees_conferred.csv")
        df_results.to_csv(file_name, index=False)
        print(f"Table saved to {file_name}.")

def extract_all_tables(cds_data_folder, full_processed_csvs_folder):
    for college_folder in os.listdir(cds_data_folder):
        if college_folder == "full_processed_csvs" or college_folder == "useful_csvs" or college_folder == ".DS_Store" or college_folder == "manual":
            continue
        college_folder_path = os.path.join(cds_data_folder, college_folder)
        for pdf_file in os.listdir(college_folder_path):
            if pdf_file.endswith('.pdf'):
                pdf_file_path = os.path.join(college_folder_path, pdf_file)
                extract_table_from_pdf(pdf_file_path, pdf_file.split(".")[0], full_processed_csvs_folder)

extract_all_tables("dataset_work/cds_data", "dataset_work/cds_data/full_processed_csvs")

# %%
# fix for colgate 2019-2021, 2023

file_path_list = ['dataset_work/cds_data/full_processed_csvs/2019/colgate_2019_degrees_conferred.csv', 
'dataset_work/cds_data/full_processed_csvs/2020/colgate_2020_degrees_conferred.csv', 
'dataset_work/cds_data/full_processed_csvs/2021/colgate_2021_degrees_conferred.csv', 
'dataset_work/cds_data/full_processed_csvs/2023/colgate_2023_degrees_conferred.csv']
for file_path in file_path_list:
    df = pd.read_csv(file_path)
    df['Bachelor’s'] = pd.to_numeric(df['Bachelor’s'], errors='coerce')
    df['Bachelor’s'] = df['Bachelor’s'] * 100
    df.to_csv(file_path, index=False)

# %%
# Clean datasets by merging columns with similar names and combining data from different years

def merge_column_names(file_path):
    df = pd.read_csv(file_path)
    if "Diploma/ Certificates" in df.columns:
        df = df.rename(columns={"Diploma/ Certificates": "Diploma/Certificates"})
    elif "Diplomas / Certificates" in df.columns:
        df = df.rename(columns={"Diplomas / Certificates": "Diploma/Certificates"})
    elif "\"Diploma/\nCertificates\"" in df.columns:
        df = df.rename(columns={"\"Diploma/\nCertificates\"": "Diploma/Certificates"})
    if "CIP 2010 Categories to Include" in df.columns:
        df = df.rename(columns={"CIP 2010 Categories to Include": "CIP Code"})
    elif "CIP Code Number" in df.columns:
        df = df.rename(columns={"CIP Code Number": "CIP Code"})
    elif "CIP 2020 Categories to Include" in df.columns:
        df = df.rename(columns={"CIP 2020 Categories to Include": "CIP Code"})
    elif "CIP 2021 Categories to Include" in df.columns:
        df = df.rename(columns={"CIP 2021 Categories to Include": "CIP Code"})
    elif "CIP202 Categories to Include" in df.columns:
        df = df.rename(columns={"CIP202 Categories to Include": "CIP Code"})
    elif "\"CIP202\nCategories\nto\nInclude\"" in df.columns:
        df = df.rename(columns={"\"CIP202\nCategories\nto\nInclude\"": "CIP Code"})
    if "Category (UM-Ann Arbor grants Bachelor's degrees; no undergraduate Diploma/Certificates or Associate degrees)" in df.columns:
        df = df.rename(columns={"Category (UM-Ann Arbor grants Bachelor's degrees; no undergraduate Diploma/Certificates or Associate degrees)": "Category"})
    if "Unnamed: 2" in df.columns:
        df = df.rename(columns={"Unnamed: 2": "Bachelor's"})
    if "Bachelor’s degrees (First majors)" in df.columns:
        df = df.drop(columns=["Bachelor’s degrees (First majors)"])
    return df
    
def merge_all_column_names(full_processed_csvs_folder):
    for year_folder in os.listdir(full_processed_csvs_folder):
        if year_folder == ".DS_Store" or year_folder == "combined":
            continue
        year_folder_path = os.path.join(full_processed_csvs_folder, year_folder)
        for college_file in os.listdir(year_folder_path):
            if college_file.endswith('.csv'):
                college_file_path = os.path.join(year_folder_path, college_file)
                df = merge_column_names(college_file_path)
                df.to_csv(college_file_path, index=False)

def combine_year_data(full_processed_csvs_folder):
    for year_folder in os.listdir(full_processed_csvs_folder):
        if year_folder == ".DS_Store" or year_folder == "combined":
            continue
        year_folder_path = os.path.join(full_processed_csvs_folder, year_folder)
        combined_df = pd.DataFrame()
        for college_file in os.listdir(year_folder_path):
            if college_file.endswith('.csv'):
                college_file_path = os.path.join(year_folder_path, college_file)
                df = pd.read_csv(college_file_path)
                df["college"] = college_file.split("_")[0]
                df["year"] = year_folder
                combined_df = pd.concat([combined_df, df], ignore_index=True)
        combined_folder = "dataset_work/cds_data/useful_csvs"
        if not os.path.exists(combined_folder):
            os.makedirs(combined_folder)
        combined_df.to_csv(os.path.join(combined_folder, f"{year_folder}_combined.csv"), index=False)

merge_all_column_names("dataset_work/cds_data/full_processed_csvs")
combine_year_data("dataset_work/cds_data/full_processed_csvs")

# %%
# Fix UMich data :///
for combined_csv in os.listdir("dataset_work/cds_data/useful_csvs"):
    df = pd.read_csv(os.path.join("dataset_work/cds_data/useful_csvs", combined_csv))
    df.replace("--", "", inplace=True)
    if "Bachelor's" in df.columns:
        pd.to_numeric(df['Bachelor’s'], errors='coerce')
        df['Bachelor’s'] = df['Bachelor’s'].combine_first(df["Bachelor's"])
        df = df.drop(columns=["Bachelor's"])
    df.to_csv(os.path.join("dataset_work/cds_data/useful_csvs", combined_csv), index=False)

# %%
# Combine data from different years into a single dataset

def combine_years(useful_csv_path):
    combined_df = pd.DataFrame()
    for file in os.listdir(useful_csv_path):
        if file.endswith('.csv') and file != 'all_years.csv':
            file_path = os.path.join(useful_csv_path, file)
            df = pd.read_csv(file_path)
            combined_df = pd.concat([combined_df, df], ignore_index=True)
    combined_df.dropna(axis=1, how='all')
    column_order = ['year', 'college', 'CIP Code', 'Category', 'Bachelor’s', 'Associate', 'Diploma/Certificates']
    combined_df = combined_df[column_order]
    combined_df = combined_df.sort_values(by=['year', 'college'], ascending=[True, True], kind='mergesort')
    combined_df.to_csv('dataset_work/cds_data/useful_csvs/all_years.csv', index=False)

combine_years('dataset_work/cds_data/useful_csvs')

# %%
df = pd.read_csv('dataset_work/cds_data/useful_csvs/all_years.csv')
print(f"DF shape: {df.shape}")
df.head()
# Out:
# DF shape: (3092, 7)
#    year college CIP Code                            Category Bachelor’s  \
# 0  2014     asu        1                         Agriculture        NaN
# 1  2014     asu        3  Natural resources and conservation       2.6%
# 2  2014     asu        4                        Architecture       0.3%
# 3  2014     asu        5    Area, ethnic, and gender studies       0.1%
# 4  2014     asu        9            Communication/journalism       6.2%
#
#   Associate Diploma/Certificates
# 0       NaN                  NaN
# 1       NaN                  NaN
# 2       NaN                  NaN
# 3       NaN                  NaN
# 4       NaN                  NaN

# %%
from difflib import get_close_matches

## Merge BLS and CDS data
## Create categorizations by checking string similarity first to fix some formatting issues, then OpenAI for category matching

# Load the CDS data
cds_df = pd.read_csv('dataset_work/cds_data/useful_csvs/all_years.csv')

# Load the combined CSV file
df_2023 = pd.read_csv("dataset_work/cds_data/useful_csvs/2023_combined.csv")
# Remove "\n" from values in the 'Category' column
df_2023['Category'] = df_2023['Category'].str.replace('\n', ' ')
# Replace specific values in the 'Category' column
df_2023['Category'] = df_2023['Category'].replace({
    'Homeland Security, law enforcement, firefighting,': 'Homeland Security, law enforcement, firefighting, and protective services',
    'TOTAL': pd.NA,
    'TOTAL (should = 100%)': pd.NA
})

# Drop rows with NaN values in the 'Category' column
df_2023.dropna(subset=['Category'], inplace=True)

# Print out the unique majors
unique_majors = df_2023['Category'].unique()
unique_majors.sort()
print(unique_majors)

# Clean up Category column
cds_df['Category'] = cds_df['Category'].str.replace('\n', ' ', regex=False)
cds_df['Category'] = cds_df['Category'].replace({
    'Homeland Security, law enforcement, firefighting,': 'Homeland Security, law enforcement, firefighting, and protective services',
    'TOTAL': pd.NA,
    'TOTAL (should = 100%)': pd.NA,
    'TOTAL(shouldbe=100%)': pd.NA
})
# Drop rows with NaN values in the 'Category' column
cds_df.dropna(subset=['Category'], inplace=True)

# Function to standardize category names
def standardize_category(category, unique_majors):
    if pd.isna(category):  # Skip NaN or None values
        return category
    # Check if the category is already in the unique_majors list
    if category in unique_majors:
        return category
    # Find the closest match to the category in unique_majors
    matches = get_close_matches(category, unique_majors)
    if matches:
        return matches[0]
    else:
        hardcoded_mappings = {
            'Biology, General': 'Biological/life sciences',
            'Economics': 'Social sciences',
            'Electrical and Electronics Engineering': 'Engineering',
            'Political Science and Government, Other': 'Social sciences'
        }
        if category in hardcoded_mappings:
            return hardcoded_mappings[category]
        return category  # Return the original if no match is found

# Apply standardization to the Category column
cds_df['Category'] = cds_df['Category'].apply(
    lambda x: standardize_category(x, unique_majors) if pd.notna(x) else x
)
# Drop the % sign and convert to int for the column Bachelor’s
cds_df['Bachelor’s'] = cds_df['Bachelor’s'].str.replace('%', '')
cds_df['Bachelor’s'] = pd.to_numeric(cds_df['Bachelor’s'], errors='coerce')

# Hard coded conversions for UCSD 2014
def hardcode_ucsd_2014_cip(row):
    if row['college'] == 'ucsd' and row['year'] == 2014:
        if row['CIP Code'] == '26.01':
            return '26'
        elif row['CIP Code'] == '45.06':
            return '45'
        elif row['CIP Code'] == '14.09':
            return '14'
        elif row['CIP Code'] == '42.0101':
            return '42'
        elif row['CIP Code'] == '14.1001':
            return '14'
    return row['CIP Code']

cds_df['CIP Code'] = cds_df.apply(hardcode_ucsd_2014_cip, axis=1)
def merge_bachelors(df):
    # Identify columns except for "Bachelor's"
    non_bachelors_columns = [col for col in df.columns if col != "Bachelor’s"]
    
    # Group by all columns except "Bachelor's" and sum the "Bachelor's" column
    merged_df = df.groupby(non_bachelors_columns, as_index=False).agg({"Bachelor’s": "sum"})
    
    return merged_df
merge_bachelors(cds_df)
# Identify all columns except for "Bachelor's"
columns_to_group_by = [col for col in cds_df.columns if col != "Bachelor’s"]

# Group by all other columns and sum the "Bachelor's" column
cds_df = cds_df.groupby(columns_to_group_by, dropna=False, as_index=False).agg({"Bachelor’s": "sum"})

# Remove all rows where Bachelor’s is 0 or NaN
cds_df = cds_df[cds_df['Bachelor’s'].notna() & (cds_df['Bachelor’s'] != 0)]
cds_df.to_csv('categorized.csv', index=False)
# Out:
# ['Agriculture' 'Architecture' 'Area, ethnic, and gender studies'
#  'Biological/life sciences' 'Business/marketing'
#  'Communication technologies' 'Communication/journalism'
#  'Computer and information sciences' 'Construction trades' 'Education'
#  'Engineering' 'Engineering technologies' 'English'
#  'Family and consumer sciences'
#  'Foreign languages, literatures, and linguistics'
#  'Health professions and related programs' 'History'
#  'Homeland Security, law enforcement, firefighting, and protective services'
#  'Interdisciplinary studies' 'Law/legal studies'
#  'Liberal arts/general studies' 'Library science'
#  'Mathematics and statistics' 'Mechanic and repair technologies'
#  'Military science and military technologies'
#  'Natural resources and conservation' 'Other' 'Parks and recreation'
#  'Personal and culinary services' 'Philosophy and religious studies'
#  'Physical sciences' 'Precision production' 'Psychology'
# ...

# %%
# OpenAI category mapping. API key is needed to run this code. 

import pandas as pd
import numpy as np
from typing import Dict, List
import openai
import openai
from time import sleep
from tqdm import tqdm
from datetime import datetime

class OpenAIMajorMapper:
    def __init__(self, api_key: str):
        self.client = openai
        self.client.api_key = api_key
        self.cache = {}
        self.stats = {
            'total_processed': 0,
            'successful_mappings': 0,
            'failed_mappings': 0,
            'start_time': None,
            'retries': 0
        }
        
    def create_prompt(self, occupation: str, majors: List[str]) -> str:
        return f"""You are a career counselor with expertise in mapping occupations to academic majors. 
Given the occupation below, select the single most appropriate academic major from the provided list.

Occupation: "{occupation}"

Available Majors:
{chr(10).join(f"- {major}" for major in majors)}

Return ONLY the exact name of the most appropriate major from the list. 
Do not add any explanations or additional text.
If no major is clearly appropriate, return "Other"."""

    def map_occupation(self, occupation: str, majors: List[str], 
                      model: str = "gpt-3.5-turbo", max_retries: int = 3) -> str:
        if occupation in self.cache:
            return self.cache[occupation]
            
        for attempt in range(max_retries):
            try:
                response = self.client.chat.completions.create(
                    model=model,
                    messages=[
                        {"role": "system", "content": "You are a career counselor who maps occupations to academic majors."},
                        {"role": "user", "content": self.create_prompt(occupation, majors)}
                    ],
                    temperature=0,
                )
                
                major = response.choices[0].message.content.strip()
                
                if major in majors or major == "Other":
                    self.cache[occupation] = major
                    self.stats['successful_mappings'] += 1
                    return major
                else:
                    self.stats['retries'] += 1
                    continue
                    
            except Exception as e:
                if attempt == max_retries - 1:
                    print(f"Error mapping {occupation}: {str(e)}")
                    self.stats['failed_mappings'] += 1
                    return "Other"
                self.stats['retries'] += 1
                sleep(1)
                
        return "Other"

    def print_status(self, current_occupation: str, total_occupations: int):
        if self.stats['start_time'] is None:
            return
        
        elapsed_time = (datetime.now() - self.stats['start_time']).total_seconds()
        avg_time_per_item = elapsed_time / max(self.stats['total_processed'], 1)
        remaining_items = total_occupations - self.stats['total_processed']
        estimated_time_remaining = remaining_items * avg_time_per_item
        
        print("\n" + "="*50)
        print(f"Current occupation: {current_occupation}")
        print(f"Progress: {self.stats['total_processed']}/{total_occupations} " 
              f"({(self.stats['total_processed']/total_occupations*100):.1f}%)")
        print(f"Successful mappings: {self.stats['successful_mappings']}")
        print(f"Failed mappings: {self.stats['failed_mappings']}")
        print(f"Total retries: {self.stats['retries']}")
        print(f"Elapsed time: {elapsed_time/60:.1f} minutes")
        print(f"Estimated time remaining: {estimated_time_remaining/60:.1f} minutes")
        print(f"Average time per item: {avg_time_per_item:.1f} seconds")
        print("="*50 + "\n")

    def map_dataframe(self, df: pd.DataFrame, occupation_column: str, 
                     majors: List[str], batch_size: int = 100) -> pd.DataFrame:
        result_df = df.copy()
        unique_occupations = df[occupation_column].unique()
        total_occupations = len(unique_occupations)
        
        self.stats['start_time'] = datetime.now()
        self.stats['total_processed'] = 0
        
        mapped_occupations = {}
        for i in range(0, len(unique_occupations), batch_size):
            batch = unique_occupations[i:i + batch_size]
            
            for occupation in batch:
                mapped_major = self.map_occupation(occupation, majors)
                mapped_occupations[occupation] = mapped_major
                self.stats['total_processed'] += 1
                
                # Print status every 10 items
                if self.stats['total_processed'] % 10 == 0:
                    self.print_status(occupation, total_occupations)
                
            self.save_progress(mapped_occupations)
        
        result_df['major_field'] = result_df[occupation_column].map(mapped_occupations)
        
        # Print final statistics
        print("\nFinal Statistics:")
        print(f"Total occupations processed: {self.stats['total_processed']}")
        print(f"Successful mappings: {self.stats['successful_mappings']}")
        print(f"Failed mappings: {self.stats['failed_mappings']}")
        print(f"Total retries: {self.stats['retries']}")
        total_time = (datetime.now() - self.stats['start_time']).total_seconds()
        print(f"Total time: {total_time/60:.1f} minutes")
        print(f"Average time per item: {total_time/self.stats['total_processed']:.1f} seconds")
        
        return result_df
    
    def save_progress(self, mapped_data: Dict[str, str], 
                     filename: str = 'occupation_mapping_progress.csv'):
        pd.DataFrame.from_dict(mapped_data, orient='index', 
                             columns=['mapped_major']).to_csv(filename)
        
    def load_progress(self, filename: str = 'occupation_mapping_progress.csv') -> Dict[str, str]:
        try:
            df = pd.read_csv(filename, index_col=0)
            return df['mapped_major'].to_dict()
        except FileNotFoundError:
            return {}

if __name__ == "__main__":
    df_2023 = pd.read_csv("dataset_work/cds_data/useful_csvs/2023_combined.csv")
    
    df_2023['Category'] = df_2023['Category'].str.replace('\n', ' ')
    df_2023['Category'] = df_2023['Category'].replace({
        'Homeland Security, law enforcement, firefighting,': 
            'Homeland Security, law enforcement, firefighting, and protective services',
        'TOTAL': pd.NA,
        'TOTAL (should = 100%)': pd.NA
    })
    
    # Drop rows with NaN values and get unique majors
    df_2023.dropna(subset=['Category'], inplace=True)
    unique_majors = sorted(df_2023['Category'].unique())
    
    # Load BLS data
    bls_df = pd.read_csv('dataset_work/bls_data/useful_csvs/all_years.csv')
    
    # Initialize mapper with your API key
    # mapper = OpenAIMajorMapper(api_key="get-your-own-openai-account-and-api-key")
    mapper = OpenAIMajorMapper(api_key="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")
    
    # Load any previous progress
    previous_mappings = mapper.load_progress()
    mapper.cache = previous_mappings
    
    # Map occupations
    result_df = mapper.map_dataframe(bls_df, 'OCC_TITLE', unique_majors)
    
    # Save final results
    result_df.to_csv('occupation_major_mapping_final.csv', index=False)
    
    # Print some statistics
    print("\nMapping Statistics:")
    print(result_df['major_field'].value_counts())
    print("\nSample mappings:")
    print(result_df[['OCC_TITLE', 'major_field']].head(10))

# %% [markdown]
# We place the cleaned data into two datasets: `colleges` and `jobs`

# %%
colleges= pd.read_csv('categorized.csv')
jobs = pd.read_csv('occupation_major_mapping_final.csv')

colleges = colleges.drop(['Associate', 'Diploma/Certificates'], axis=1)
colleges = colleges.rename(columns={'year': 'Year', 'college': 'College'})

jobs = jobs[['YEAR', 'AREA_TITLE', 'OCC_GROUP', 'OCC_TITLE', 'TOT_EMP', 'major_field']]
jobs = jobs.rename(columns={'YEAR': 'Year', 'AREA_TITLE': 'Area', 'OCC_GROUP': 'Occupation Group', 'OCC_TITLE': 'Occupation Title', 'TOT_EMP': 'Total Employment', 'major_field': 'Major Field'})
jobs['Total Employment'] = pd.to_numeric(jobs['Total Employment'], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# We noticed that some CDS categories were very similar, such as Engineering vs. Engineering Technologies. We also noticed that schools would place all their bachelor's in either one or the other category (for example, all their engineering-related bachelor's in Engineering vs. all their engineering-related bachelor's in Engineering Technology), while jobs would be categorized into both. To simplify this and give us more accurate counts, we chose to combine similar fields together in both the college major and job data.

# %%
# Merge some majors together to reduce the number of unique majors :)
# Done with OpenAI
# Prompt given: Imagine you are a college counselor, and a student tells you they want to do one of the following majors {original major list}. 
# The college they are applying for only has 20 majors (you can choose which 20, or make up broader categories). 
# Please map the student's major to the most appropriate major from the list.

majors_merged = {
    'Agriculture': 'Agriculture',
    'Architecture': 'Architecture',
    'Area, ethnic, and gender studies': 'Social sciences',
    'Biological/life sciences': 'Biological sciences',
    'Business/marketing': 'Business',
    'Communication technologies': 'Communication and media',
    'Communication/journalism': 'Communication and media',
    'Computer and information sciences': 'Computer science',
    'Construction trades': 'Construction and trades',
    'Education': 'Education',
    'Engineering': 'Engineering',
    'Engineering technologies': 'Engineering',
    'English': 'Humanities',
    'Family and consumer sciences': 'Social sciences',
    'Foreign languages, literatures, and linguistics': 'Humanities',
    'Health professions and related programs': 'Health sciences',
    'History': 'Humanities',
    'Homeland Security, law enforcement, firefighting, and protective services': 'Public safety',
    'Interdisciplinary studies': 'Social sciences',
    'Law/legal studies': 'Law',
    'Liberal arts/general studies': 'Social sciences',
    'Library science': 'Education',
    'Mathematics and statistics': 'Mathematics',
    'Mechanic and repair technologies': 'Construction and trades',
    'Military science and military technologies': 'Public safety',
    'Natural resources and conservation': 'Environmental sciences',
    'Parks and recreation': 'Hospitality and recreation',
    'Personal and culinary services': 'Hospitality and recreation',
    'Philosophy and religious studies': 'Humanities',
    'Physical sciences': 'Physical sciences',
    'Precision production': 'Construction and trades',
    'Psychology': 'Social sciences',
    'Public administration and social services': 'Public administration',
    'Science technologies': 'Physical sciences',
    'Social sciences': 'Social sciences',
    'Theology and religious vocations': 'Humanities',
    'Transportation and materials moving': 'Construction and trades',
    'Visual and performing arts': 'Arts'
}

colleges['Category'] = colleges['Category'].map(majors_merged).fillna(colleges['Category'])
jobs['Major Field'] = jobs['Major Field'].map(majors_merged).fillna(jobs['Major Field'])

unique_college_categories = sorted(colleges['Category'].unique())
print("Unique categories in colleges:")
print(unique_college_categories)

unique_job_fields = sorted(jobs['Major Field'].unique())
print("\nUnique major fields in jobs:")
print(unique_job_fields)

# Fix data set error with Occupation Group

jobs.loc[jobs['Occupation Title'] == 'All Occupations', 'Occupation Group'] = 'total'
# Out:
# Unique categories in colleges:
# ['Agriculture', 'Architecture', 'Arts', 'Biological sciences', 'Business', 'Communication and media', 'Computer science', 'Education', 'Engineering', 'Environmental sciences', 'Health sciences', 'Hospitality and recreation', 'Humanities', 'Mathematics', 'Other', 'Physical sciences', 'Public administration', 'Public safety', 'Social sciences']
#
# Unique major fields in jobs:
# ['Agriculture', 'Architecture', 'Arts', 'Biological sciences', 'Business', 'Communication and media', 'Computer science', 'Construction and trades', 'Education', 'Engineering', 'Environmental sciences', 'Health sciences', 'Hospitality and recreation', 'Humanities', 'Law', 'Mathematics', 'Other', 'Physical sciences', 'Public administration', 'Public safety', 'Social sciences']

# %%
# add proportions to job data set
jobs = pd.read_csv('jobs_manual_fix.csv')
total_employment_dict = jobs[jobs['Occupation Title'] == 'All Occupations'].set_index(['Year', 'Area'])['Total Employment'].to_dict()

def calculate_proportion(row):
    key = (row['Year'], row['Area'])
    if key in total_employment_dict:
        if (100 < row['Total Employment'] / total_employment_dict[key] * 100):
            print(f"Error: Proportion outside of range for {row['Occupation Title']} in {row['Year']}; {row['Total Employment'] / total_employment_dict[key] * 100}")
        return row['Total Employment'] / total_employment_dict[key] * 100
    else:
        print(f"Key not found: {key}")
        return None

jobs['Proportions'] = jobs.apply(calculate_proportion, axis=1)
colleges.rename(columns={'Bachelor’s': 'Bachelors'}, inplace=True)

jobs.to_csv('jobs_manual_output.csv', index=False)
colleges.to_csv('colleges.csv', index=False)

# %%
# Merge major categories

def sum_degrees_by_major(college_df):
    colleges = pd.DataFrame(columns=['Year', 'College', 'Category', 'Bachelors'])
    for index, row in college_df.iterrows():
        year = row['Year']
        college = row['College']
        category = row['Category']
        bachelor = row['Bachelors']
        
        if ((colleges['Year'] == year) & (colleges['College'] == college) & (colleges['Category'] == category)).any():
            colleges.loc[(colleges['Year'] == year) & (colleges['College'] == college) & (colleges['Category'] == category), 'Bachelors'] += bachelor
        else:
            colleges.loc[len(colleges)] = {'Year': year, 'College': college, 'Category': category, 'Bachelors': bachelor}
    return colleges

colleges = pd.read_csv('colleges.csv')
colleges = sum_degrees_by_major(colleges)
colleges.to_csv('colleges.csv', index=False)

# %% [markdown]
# Since we saved all of our cleaned data into `.csv` files, we can read from the new cleaned `.csv` files each time we need to refresh our notebook.

# %%
colleges = pd.read_csv('colleges.csv')
jobs = pd.read_csv('jobs_manual_output.csv')

# %%
colleges.head()
# Out:
#    Year College          Category  Bachelors
# 0  2014     asu  Computer science        1.0
# 1  2014     asu         Education       13.8
# 2  2014     asu       Engineering        1.9
# 3  2014     asu        Humanities        5.5
# 4  2014     asu   Social sciences       17.0

# %%
jobs.head()
# Out:
#    Year           Area Occupation Group                 Occupation Title  \
# 0  2006  Ann Arbor, MI            total                  All Occupations
# 1  2006  Ann Arbor, MI            major           Management occupations
# 2  2006  Ann Arbor, MI              NaN                 Chief executives
# 3  2006  Ann Arbor, MI              NaN  General and operations managers
# 4  2006  Ann Arbor, MI              NaN                      Legislators
#
#    Total Employment            Major Field  Proportions
# 0            197810                  Other   100.000000
# 1              8060               Business     4.074617
# 2               540               Business     0.272989
# 3              1670               Business     0.844244
# 4                30  Public administration     0.015166

# %% [markdown]
# # Results
#
# ## Exploratory Data Analysis

# %% [markdown]
# ### Major and Job Trends
#
# We chose to investigate eight separate colleges with different major makeups and populations, as well as their corresponding metropolitan areas. They are as follows:
#
# - University of California San Diego (UCSD) vs. San Diego/Carlsbad
# - University of Michigan (UMich) vs. Ann Arbor
# - California Institute of Technology (CalTech) vs. Los Angeles/Long Beach/Anaheim
# - Georgetown University (Georgetown) vs. Washington DC
# - Appalachian State University (ASU) vs. Winston-Salem
# - Dartmouth College (Dartmouth) vs. West/Central/Southwest New Hampshire
# - Colgate University (Colgate) vs. Utica/Rome or Syracruse
# - Washington State University (WSU) vs. Spokane
#
# Our hypothesis was that students' major choices are influenced by the job market; thus, if we see an increase in the proportion of one job, we would see an increase in the proportion of the corresponding major and vice versa. To analyze this visually, we want to create line plots that observe the changes in the proportions of majors at each of our eight colleges and compare them to trends in job fields.
#
# We also asked if students are more influenced by the national job market or those of the area around their school. Thus, we want to compare the changes in major proportions to both changes in the overall proportions of the national job market (or the combined total jobs of our entire job dataset) and changes in the local job market (by looking at the changes in proportion for each college's metropolitan area).

# %% [markdown]
# ### National Job Trends
#
# This graph shows job trends from 2014-2023. For visual clarity, we chose the top 10 fields present.

# %%
# Sort dataframes to group by area and year
jobs_2014_2023 = jobs[(jobs['Occupation Group'] == 'major') & (jobs['Year'] >= 2014) & (jobs['Year'] <= 2023)]
jobs_2014_2023 = jobs_2014_2023.groupby(['Year', 'Major Field']).sum().reset_index() # total employment
jobs_total = jobs_2014_2023.groupby(['Year']).sum().reset_index() # total employment

# Create function to calculate total proportions based on year
def calculate_total_proportions(row):
    curYear = row['Year']
    curTotal = int(jobs_total[jobs_total['Year'] == curYear]['Total Employment'])
    return (row['Total Employment'] / curTotal)

jobs_2014_2023['Yearly Proportions'] = jobs_2014_2023.apply(calculate_total_proportions, axis=1)
top_ten = jobs_2014_2023.groupby('Major Field')['Total Employment'].sum().reset_index()
top_ten = top_ten.sort_values(by='Total Employment', ascending=False)[:10]

jobs_filtered = jobs_2014_2023[(jobs_2014_2023['Major Field'].isin(top_ten['Major Field']))]

# %%
plot, ax = plt.subplots(figsize=(18, 8))
plot = sns.lineplot(data=jobs_filtered, x='Year',y='Yearly Proportions', hue='Major Field', marker='o', palette='tab10')
sns.move_legend(plot, "upper left", bbox_to_anchor=(1, 1))

ax.set_title('Job Distribution Changes Over Time (2014-2023) in All Selected Metropolitan Areas')
# ax.set_yscale('log')
ax.set_xlabel('Year')
ax.set_ylabel('Proportion of Total Employment')
plt.tight_layout()

plt.show()

# %% [markdown]
# As we can see, business is the most popular major in our metropolitan areas; however, it shows a slow decline over time. The most noticeable trend is a jump in health sciences in 2019 (right at the start of the pandemic), so it would be interesting to see if there are any increases in health sciences in our colleges. Most other job markets remain relatively stable; minor trends include the small peak, fall, and then stabilization of hospitality and recreation and the dip in computer science between 2017 and 2018.

# %% [markdown]
# ### All Colleges
#
# To make our analysis quicker, let's create functions that will plot graphs given both college and city data. We'll also create a function that helps us recolor the graphs so that major fields that are same between the college and city graph are the same, making it easier to see the difference in trends between the two.

# %%
# This function creates a graph of the trends of the top 10 majors at a given college

def college_graph(data_name, real_name, colors):
    # gets all data for the college
    majors = colleges[(colleges['College'] == data_name) & (colleges['Year'] >= 2014) & (colleges['Year'] <= 2023)].copy()

    # modifies proportions to be out of 1, instead of 100
    majors['Bachelors'] = majors['Bachelors']/100

    # groups data by year and category
    major_distribution = majors.groupby(['Year', 'Category']).sum().reset_index()

    # finds top ten majors
    top_ten = major_distribution.groupby('Category')['Bachelors'].sum().reset_index().sort_values(by='Bachelors', ascending=False)[:10]

    # filters data to only include top ten majors
    major_filtered = major_distribution[(major_distribution['Category'].isin(top_ten['Category']))]

    # create plot
    fig, ax = plt.subplots(figsize=(18, 8))
    fig = sns.lineplot(data=major_filtered, x='Year', y='Bachelors', hue='Category', marker='o', palette=colors)
    sns.move_legend(fig, "upper left", bbox_to_anchor=(1,1))
    ax.set_title("Major Distribution Changes at " + real_name)
    ax.set_xlabel('Year')
    ax.set_ylabel('Proportion of Total Bachelors Awarded')
    plt.tight_layout()

    plt.show()

# %%
# This function creates a graph of the trends of the top 10 job fields in a given metropolitan area

def job_graph(data_name, real_name, colors):
    # gets all data for the area
    fields = jobs[(jobs['Area'] == data_name) & (jobs['Year'] >= 2014) & (jobs['Year'] <= 2023) & (jobs['Occupation Group'] == 'major')].copy()

    # groups data by year and category
    field_distribution = fields.groupby(['Year', 'Major Field']).sum().reset_index()

    # finds top ten majors
    top_ten = field_distribution.groupby('Major Field')['Total Employment'].sum().reset_index().sort_values(by='Total Employment', ascending=False)[:10]

    # filters data to only include top ten majors
    jobs_filtered = field_distribution[(field_distribution['Major Field'].isin(top_ten['Major Field']))]

    # create plot
    fig, ax = plt.subplots(figsize=(18, 8))
    fig = sns.lineplot(data=jobs_filtered, x='Year', y='Proportions', hue='Major Field', marker='o', palette=colors)
    sns.move_legend(fig, "upper left", bbox_to_anchor=(1,1))
    ax.set_title("Job Field Distribution Changes in " + real_name)
    ax.set_xlabel('Year')
    ax.set_ylabel('Proportion of Total Jobs')
    plt.tight_layout()

    plt.show()

# %%
# This function returns a dictionary object that helps overlapping majors between the top 10 of colleges and top 10 of cities be the same between both graphs

def color_graph(college_name, city_name):
    # gets top ten majors for colleges
    majors = colleges[(colleges['College'] == college_name) & (colleges['Year'] >= 2014) & (colleges['Year'] <= 2023)].copy()
    majors['Bachelors'] = majors['Bachelors']/100
    major_distribution = majors.groupby(['Year', 'Category']).sum().reset_index()
    top_ten_college = major_distribution.groupby('Category')['Bachelors'].sum().reset_index().sort_values(by='Bachelors', ascending=False)[:10]
    top_ten_college = top_ten_college['Category'].to_numpy()

    # gets top ten major fields for cities
    fields = jobs[(jobs['Area'] == city_name) & (jobs['Year'] >= 2014) & (jobs['Year'] <= 2023) & (jobs['Occupation Group'] == 'major')].copy()
    field_distribution = fields.groupby(['Year', 'Major Field']).sum().reset_index()
    top_ten_city = field_distribution.groupby('Major Field')['Total Employment'].sum().reset_index().sort_values(by='Total Employment', ascending=False)[:10]
    top_ten_city = top_ten_city['Major Field'].to_numpy()

    # combine into a list of all top majors
    top_majors = list(top_ten_college)
    top_majors.extend(x for x in top_ten_city if x not in top_majors)

    colors = {}
    # loop through majors and add to colors
    cm = plt.get_cmap('tab20')
    curColor = iter(cm(np.linspace(0, 1, len(top_majors))))
    for major in top_majors:
        colors[major] = next(curColor)

    return colors

# %% [markdown]
# ### UCSD vs. San Diego-Carlsbad
#
# It is worth noting that between 2014-2017, UCSD did not properly report major distributions, only including Biology, Economics, Computer Engineering, Psychology, Communication, and Other, with nearly half of all diplomas awarded landing in the "Other" section. Thus, data from 2017 onwards is more accurate, but we still want to include earlier data since it still reveals important trends for those majors.

# %%
colors = color_graph('ucsd', 'San Diego-Carlsbad, CA')
college_graph('ucsd', 'UCSD', colors)
job_graph('San Diego-Carlsbad, CA', 'San Diego-Carlsbad, CA', colors)

# %% [markdown]
# It appears from these two graphs that the local San Diego job market has little impact on UCSD students' choices of majors. For example, the proportion of individuals majoring in the social sciences has jumped from 2014 to 2023, but the job proportion remained relatively the same between the same time period. The most popular job category in San Diego, business, is not even within the top 10 majors at UCSD.
#
# Similarly, it appears that national job trends do not heavily affect UCSD students' choices of majors either. The job trends of San Diego are very similar to those of the national job market and its employment demands. This may possibly suggest that major selection of undergraduate students at UCSD are guided more on personal interests or other factors that are independent from market demands.

# %% [markdown]
# ### UMich vs. Ann Arbor

# %%
colors = color_graph('umich', 'Ann Arbor, MI')
college_graph('umich', 'University of Michigan', colors)
job_graph('Ann Arbor, MI', 'Ann Arbor, MI', colors)

# %% [markdown]
# As illustrated from the two graphs above, it is apparent that the local job market in Michigan has a moderate impact on the selection of undergraduate majors in UMICH. Fields such as Computer Science and Engineering have seen significant increases in popularity from 2014 to 2023 which aligns with the local demand in Michigan. Other fields such as Arts and Humanities have also demonstrated notable growth in major selection by students, but do not correlate with local job trends.
#
# The job trends of Ann Arbor in Michigan closely match those of the national job market with Business being the highest demand in both graphs. Computer Science has demonstrated increasing growth as well in proportions throughout 2014 to 2023. National job trends appear to partially influence UMICH students’ selection of majors as reflected by the popularity in fields such as Computer Science and Engineering.

# %% [markdown]
# ### CalTech vs. Los Angeles/Long Beach/Anaheim

# %%
colors = color_graph('caltech', 'Los Angeles-Long Beach-Anaheim, CA')
college_graph('caltech', 'CalTech', colors)
job_graph('Los Angeles-Long Beach-Anaheim, CA', 'Los Angeles-Long Beach-Anaheim, CA', colors)

# %% [markdown]
# Looking at the two graphs above, it appears that the local job market has little impact on the major selection of CalTech students. For example, the proportion of individuals who chose to major in Computer Science and Engineering have increased significantly from 2014 to 2023, but the job proportion remained relatively the same with Business and Construction/Trades being the highest proportions.
#
# It appears that the national job trends also do not heavily affect CalTech students’ choices of majors as well. The job trends within Los Angeles/LongBeach/Anaheim are extremely similar to the national job market, with both graphs having Business and Construction/Trades being the highest in demand and proportions. This may possibly suggest that major selection of undergraduate students at Caltech are more based on personal interests and other factors that have no relation with market demands.

# %% [markdown]
# ### Georgetown vs. Washington DC

# %%
colors = color_graph('george', 'Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Division')
college_graph('george', 'Georgetown', colors)
job_graph('Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Division', 'Washington DC', colors)

# %% [markdown]
# As demonstrated by the two graphs above, it appears that the Washington DC job market has a moderate impact on the students major selection at Georgetown. The major distribution demonstrates that the highest proportions in major selection of undergraduates are Social Sciences and Business, both of which either increased in popularity or have remained relatively the same throughout 2014 to 2023. Though the local market has demonstrated a decrease in proportion in business occupations, it still remains the highest with Construction/Trades and Social Sciences following which reflects that these demands may influence Georgetown students’ selection of majors.
#
# Similarly, it appears that the local market trends closely mirror those of the national job market with Business and Construction/Trades being the highest demand in both graphs. These high proportions suggest that national job trends have a moderate impact on undergraduate major selection at Georgetown as well and that major choices may be influenced by the national job market.

# %% [markdown]
# ### ASU vs. Winston-Salem

# %%
colors = color_graph('asu', 'Winston-Salem, NC')
college_graph('asu', 'Appalachian State University', colors)
job_graph('Winston-Salem, NC', 'Winston-Salem, NC', colors)

# %% [markdown]
# From seeing the two graphs, it seems to be that the Winston-Salem job market does have an impact on the students of Appalachian State University. On the major distribution changes at ASU, it does show the proportion of students that are taking majors in the category of business is at the top for every year from 2014 to 2023.
#
# When looking at the job trends, it does show that the job trends of Winston-Salem are similar to the national job trends that are shown, with business leading as the largest proportion of jobs and construction and trades one behind.  Based on all of this, it may suggest that students at ASU are possibly guided on the national job market when deciding the major they want to pursue.

# %% [markdown]
# ### Dartmouth vs. West/Central/Southwest New Hampshire

# %%
colors = color_graph('dartmouth', 'West Central-Southwest New Hampshire nonmetropolitan area')
college_graph('dartmouth', 'Dartmouth', colors)
job_graph('West Central-Southwest New Hampshire nonmetropolitan area', 'West/Central/Southwest New Hampshire', colors)

# %% [markdown]
# As seen in the graphs, the job market in West/Central/Southwest New Hampshire does not seem to impact Dartmouth College. The major distribution of Dartmouth shows that the largest proportion of majors in Dartmouth is in the Social Sciences, which drastically was the frontrunner in the major choice from 2014 to 2023. This is very different from what is seen in the jobs in West/Central/Southwest New Hampshire, where the job market seems to have the highest proportion in Business. While there was a massive decrease in the proportion for business occupations from 2017 onward, it is still the highest proportion with Construction and trades being second in proportion.
#
# Looking at the national job trends, however, seems to paint a picture that the trends are very similar to each other, thus additionally not affecting the major choices of Dartmouth students. In both graphs, it is seen that the top 3 jobs that are in demand are Business, Construction and trades, and Health sciences. This all could suggest that the major selection of the students are more based on personal values or values of the college and not of the market trends, as Dartmouth is well known for its humanities.

# %% [markdown]
# ### Colgate vs. Utica-Rome

# %%
colors = color_graph('colgate', 'Utica-Rome, NY')
college_graph('colgate', 'Colgate University', colors)
job_graph('Utica-Rome, NY', 'Utica-Rome, NY', colors)

# %% [markdown]
# Focusing on the two graphs above, it seems to be that the local job market in Utica-Rome has little to no impact on the major selection of students in Colgate University. In looking at the proportions in Colgate University, it shows that the proportion of students who chose social sciences as their major was far and away the most of all the other 10 majors from 2014 to 2023.
#
# In comparison, the job market for Utica-Rome over that same time period showed that business was the largest, with Construction and trades and Health Sciences being 2 and 3rd in different years. Comparing the local market trend with the national one, we can see a similar story, as business leads while Construction and trades and Health Sciences are the next two highest. This could suggest that, similar to Dartmouth, that students at Colgate look at different things to guide them towards the major that they chose.

# %% [markdown]
# ### WSU vs. Spokane

# %%
colors = color_graph('wsu', 'Spokane-Spokane Valley, WA')
college_graph('wsu', 'Washington State University', colors)
job_graph('Spokane-Spokane Valley, WA', 'Spokane, WA', colors)

# %% [markdown]
# Observing the major distribution for Washington State University, it could be seen that the local job market has a small to moderate impact on students choosing their majors. The Social Sciences field seems to have the largest popularity among students from 2014 to 2024, with Business coming second, which aligns slightly with the local job trends. The job market trends in Spokane show that business has the highest demand, with Construction and trades and Health Sciences coming right after.
#
# When compared to the national job trends, it matches those of Spokane closely, with Business, Construction and trades, and Health Sciences coming 1st, 2nd, and 3rd respectively. Based on all of this, it does seem that both the national and the local job trends do  have a slight influence on the students that go to Washington State.

# %% [markdown]
# ### EDA Conclusion
#
# Overall, it appears that the job market, both national and local, may have a smaller impact on individual major choice than we originally hypothesized. Only three schools (Georgetown, ASU, and WSU) seem affected by the job trends shown in our EDA. However, we still need to perform statistical tests to come to a conclusion. Given the EDA, we expect some schools to possibly show a statistical difference, but a majority of them might not.

# %% [markdown]
# # Data Analysis

# %%
# import necessary libraries for analysis

# %pip install scipy
# %pip install statsmodels

from scipy.stats import ttest_rel, ttest_ind, spearmanr
from statsmodels.stats.multitest import multipletests
import pandas as pd
import matplotlib.pyplot as plt

# %%
# run a paired t-test for: 
# bachelor's degree proportions for a certain college, certain year
# compared to the job field proportions for a certain area (either local or national), certain year (between 6 years before to the same year)
# find the p-values for the t-tests and save them for future use

jobs = pd.read_csv('jobs_manual_output.csv')
colleges = pd.read_csv('colleges.csv')

colleges.rename(columns={'Category': 'Major Field'}, inplace=True)

# needed for when the area is all
def calculate_national_proportions(jobs_df, year):
    major_rows = jobs_df[(jobs_df['Year'] == year) & (jobs_df['Occupation Group'] == 'major')].copy()
    national_total = major_rows['Total Employment'].sum()
    major_rows['Proportions'] = (major_rows['Total Employment'] / national_total) * 100
    return major_rows

# after each job was assigned a major field, combine it so that jobs are split by major field rather than occupation
def sum_employment_by_major(job_df, college, college_year, job_year, area):
    input_sum = job_df['Proportions'].sum()
    if not (99 <= input_sum <= 101):
        print(f"College: {college}, Job Year: {job_year}, College Year: {college_year}, Area: {area}")
        print(f"Warning: Input proportions sum to {input_sum:.2f}%")
    employment_df = pd.DataFrame(columns=['Major Field', 'Total Employment', 'Proportions'])
    for index, row in job_df.iterrows():
        major = row['Major Field']
        employment = row['Total Employment']
        proportions = row['Proportions']
        
        if major in employment_df['Major Field'].values:
            employment_df.loc[employment_df['Major Field'] == major, 'Total Employment'] += employment
            employment_df.loc[employment_df['Major Field'] == major, 'Proportions'] += proportions
        else:
            employment_df.loc[len(employment_df)] = {'Major Field': major, 'Total Employment': employment, 'Proportions': proportions, 'Job Year': job_year}
    
    total = employment_df['Proportions'].sum()
    if not (99 <= total <= 101):
        print(f"Warning: Output proportions sum to {total:.2f}%")
    return employment_df

def compare_job_to_college(jobs, colleges, college, college_year, job_year, area):
    if area == 'all':
        jobs_df = jobs[jobs['Year'] == job_year]
        jobs_df = calculate_national_proportions(jobs_df, job_year)
    else:
        jobs_df = jobs[jobs['Occupation Group'] == 'major']
        jobs_df = jobs_df[(jobs_df['Year'] == job_year) & (jobs_df['Area'] == area)]
        jobs_df = jobs_df[(jobs_df['Occupation Group'] == 'major')].copy()
        area_total = jobs_df['Total Employment'].sum()
        jobs_df['Proportions'] = (jobs_df['Total Employment'] / area_total) * 100

    college_df = colleges[(colleges['Year'] == college_year) & (colleges['College'] == college)]
    job_employment_df = sum_employment_by_major(jobs_df, college, college_year, job_year, area)
    combined_df = pd.merge(college_df, job_employment_df, on='Major Field', how='outer')
    combined_df['Total Employment'] = combined_df['Total Employment'].fillna(0)
    combined_df['Proportions'] = combined_df['Proportions'].fillna(0)
    combined_df['Bachelors'] = combined_df['Bachelors'].fillna(0)
    combined_df['Year'] = college_year
    combined_df.rename(columns={'Year': 'College Year'}, inplace=True)
    combined_df['College'] = college
    combined_df['Job Year'] = job_year
    combined_df['Area'] = area
    _, p = ttest_rel(combined_df['Proportions'], combined_df['Bachelors'])
    return p, combined_df
    
college_to_area_map = {
    'ucsd': "San Diego-Carlsbad, CA",
    'asu': "Winston-Salem, NC",
    'colgate': "Utica-Rome, NY",
    'dartmouth': "West Central-Southwest New Hampshire nonmetropolitan area",
    'caltech': "Los Angeles-Long Beach-Anaheim, CA",
    'george': "Washington-Arlington-Alexandria, DC-VA-MD-WV Metropolitan Division",
    'umich': "Ann Arbor, MI",
    'wsu': "Spokane-Spokane Valley, WA"
}

combined = pd.DataFrame(columns=['College', 'College Year', 'Job Year', 'Major Field', 'Bachelors', 'Total Employment', 'Proportions', 'Area'])
p_value_df = pd.DataFrame(columns=['College', 'College Year', 'Job Year', 'Area', 'P-Value'])
for key in college_to_area_map.keys():
    for year in range(2014, 2023):
        for area in ['all', college_to_area_map[key]]:
            for i in range(-6, 1):
                if year + i in range(2006, 2023):
                    college_year = year
                    job_year = year + i
                    # uncomment the next line to run
                    p_value, combined_df = compare_job_to_college(jobs, colleges, key, college_year, job_year, area)
                    combined = pd.concat([combined, combined_df])
                    p_value_df.loc[len(p_value_df)] = {'College': key, 'College Year': college_year, 'Job Year': job_year, 'Area': area, 'P-Value': p_value}

print(p_value_df)
# Out:
# /var/folders/_n/cr1b7bs150966hbbw84jhb9m0000gn/T/ipykernel_73729/2390743375.py:88: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat([combined, combined_df])
#      College  College Year  Job Year                        Area  P-Value
# 0       ucsd          2014      2008                         all      1.0
# 1       ucsd          2014      2009                         all      1.0
# 2       ucsd          2014      2010                         all      1.0
# 3       ucsd          2014      2011                         all      1.0
# 4       ucsd          2014      2012                         all      1.0
# ...      ...           ...       ...                         ...      ...
# ...

# %%
# write to csv so other people don't have to run 24 mins of code
p_value_df.to_csv('p_value.csv', index=False)
combined.to_csv('combined.csv', index=False)

# print out significant p-values; and then also just check the 5 lowest p-values
for index, row in p_value_df.iterrows():
    if row['P-Value'] < 0.05:
        print(f"School: {row['College']}, College Year: {row['College Year']}, Job Year: {row['Job Year']}, Area: {row['Area']}, P-Value: {row['P-Value']}")
significant_p_values = p_value_df[p_value_df['P-Value'] < 0.05]
p_value_df = p_value_df.sort_values(by='P-Value')
print(p_value_df.head())
# Out:
#      College  College Year  Job Year            Area   P-Value
# 372  colgate          2022      2017  Utica-Rome, NY  0.854725
# 374  colgate          2022      2019  Utica-Rome, NY  0.855343
# 373  colgate          2022      2018  Utica-Rome, NY  0.856374
# 371  colgate          2022      2016  Utica-Rome, NY  0.856486
# 377  colgate          2022      2022  Utica-Rome, NY  0.856580

# %%
# same as above comparison, only we want to remove any 0 fields because those could skew results

def compare_job_to_college_remove_zeros(jobs, colleges, college, college_year, job_year, area):
    if area == 'all':
        jobs_df = jobs[jobs['Year'] == job_year]
        jobs_df = calculate_national_proportions(jobs_df, job_year)
    else:
        jobs_df = jobs[jobs['Occupation Group'] == 'major']
        jobs_df = jobs_df[(jobs_df['Year'] == job_year) & (jobs_df['Area'] == area)]
        jobs_df = jobs_df[(jobs_df['Occupation Group'] == 'major')].copy()
        area_total = jobs_df['Total Employment'].sum()
        jobs_df['Proportions'] = (jobs_df['Total Employment'] / area_total) * 100

    college_df = colleges[(colleges['Year'] == college_year) & (colleges['College'] == college)]
    job_employment_df = sum_employment_by_major(jobs_df, college, college_year, job_year, area)
    combined_df = pd.merge(college_df, job_employment_df, on='Major Field', how='outer')
    combined_df['Total Employment'] = combined_df['Total Employment'].fillna(0)
    combined_df['Proportions'] = combined_df['Proportions'].fillna(0)
    combined_df['Bachelors'] = combined_df['Bachelors'].fillna(0)
    combined_df['Year'] = college_year
    combined_df.rename(columns={'Year': 'College Year'}, inplace=True)
    combined_df['College'] = college
    combined_df['Job Year'] = job_year
    combined_df['Area'] = area
    combined_df = combined_df[(combined_df['Proportions'] > 0) & (combined_df['Bachelors'] > 0)]
    _, p = ttest_rel(combined_df['Proportions'], combined_df['Bachelors'])
    return p, combined_df

combined = pd.DataFrame(columns=['College', 'College Year', 'Job Year', 'Major Field', 'Bachelors', 'Total Employment', 'Proportions', 'Area'])
p_value_df = pd.DataFrame(columns=['College', 'College Year', 'Job Year', 'Area', 'P-Value'])
for key in college_to_area_map.keys():
    for year in range(2014, 2023):
        for area in ['all', college_to_area_map[key]]:
            for i in range(-6, 1):
                if year + i in range(2006, 2023):
                    college_year = year
                    job_year = year + i
                    # uncomment the next line to run
                    p_value, combined_df = compare_job_to_college_remove_zeros(jobs, colleges, key, college_year, job_year, area)
                    combined = pd.concat([combined, combined_df], ignore_index=True)
                    p_value_df.loc[len(p_value_df)] = {'College': key, 'College Year': college_year, 'Job Year': job_year, 'Area': area, 'P-Value': p_value}

print(p_value_df)
# Out:
# /var/folders/_n/cr1b7bs150966hbbw84jhb9m0000gn/T/ipykernel_73729/2587199972.py:40: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined = pd.concat([combined, combined_df], ignore_index=True)
#      College  College Year  Job Year                        Area   P-Value
# 0       ucsd          2014      2008                         all  0.230570
# 1       ucsd          2014      2009                         all  0.230571
# 2       ucsd          2014      2010                         all  0.065819
# 3       ucsd          2014      2011                         all  0.059525
# 4       ucsd          2014      2012                         all  0.052499
# ...      ...           ...       ...                         ...       ...
# ...

# %%
# write to csv so other people don't have to run 24 mins of code
p_value_df.to_csv('altered_p_value.csv', index=False)
combined.to_csv('altered_combined.csv', index=False)

p_value_df = pd.read_csv('altered_p_value.csv')

# print out significant p-values and also lowest 10 p-values
for index, row in p_value_df.iterrows():
    if row['P-Value'] < 0.05:
        print(f"School: {row['College']}, College Year: {row['College Year']}, Job Year: {row['Job Year']}, Area: {row['Area']}, P-Value: {row['P-Value']}")
significant_p_values = p_value_df[p_value_df['P-Value'] < 0.05]
p_value_df = p_value_df.sort_values(by='P-Value')
print(p_value_df.head(10))
# Out:
# School: ucsd, College Year: 2014, Job Year: 2013, Area: all, P-Value: 0.0385783116123769
# School: ucsd, College Year: 2014, Job Year: 2014, Area: all, P-Value: 0.0286587819016932
# School: ucsd, College Year: 2014, Job Year: 2010, Area: San Diego-Carlsbad, CA, P-Value: 0.0131394949528472
# School: ucsd, College Year: 2014, Job Year: 2011, Area: San Diego-Carlsbad, CA, P-Value: 0.023409004745433
# School: ucsd, College Year: 2014, Job Year: 2012, Area: San Diego-Carlsbad, CA, P-Value: 0.0295215511266978
# School: ucsd, College Year: 2014, Job Year: 2013, Area: San Diego-Carlsbad, CA, P-Value: 0.0308557128359012
# School: ucsd, College Year: 2014, Job Year: 2014, Area: San Diego-Carlsbad, CA, P-Value: 0.0467531143411289
#    College  College Year  Job Year                    Area   P-Value
# 9     ucsd          2014      2010  San Diego-Carlsbad, CA  0.013139
# 10    ucsd          2014      2011  San Diego-Carlsbad, CA  0.023409
# ...

# %%
# find the Spearman correlation between the two variable sets, and graph them. Only for significant p-values

combined = pd.read_csv('combined.csv')
altered_p_values = pd.read_csv('p_value.csv')

# Filter significant p-values first
significant_p_values = altered_p_values[altered_p_values['P-Value'] < 0.05]
num_plots = len(significant_p_values)
rows = (num_plots + 2) // 3 
cols = min(3, num_plots)

plt.figure(figsize=(15, 5*rows))

for i, (_, row) in enumerate(significant_p_values.iterrows()):
    college = row['College']
    college_year = row['College Year']
    job_year = row['Job Year']
    area = row['Area']
    p_value = row['P-Value']
    
    # Get the matching data from combined DataFrame
    specific_df = combined[
        (combined['College'] == college) & 
        (combined['College Year'] == college_year) & 
        (combined['Area'] == area) & 
        (combined['Job Year'] == job_year)
    ]
    
    if not specific_df.empty:
        # Calculate Spearman correlation
        correlation, _ = spearmanr(specific_df['Proportions'], specific_df['Bachelors'])
        
        plt.subplot(rows, cols, i+1)
        plt.scatter(specific_df['Proportions'], specific_df['Bachelors'], alpha=0.6)
        plt.xlabel('Proportions')
        plt.ylabel('Bachelors')
        plt.title(f'{college} ({area}:{college_year}-{job_year})\np={p_value:.3f}, r={correlation:.3f}')
        plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# same thing as above, but for the 0-corrected data

combined = pd.read_csv('altered_combined.csv')
altered_p_values = pd.read_csv('altered_p_value.csv')

# Filter significant p-values first
significant_p_values = altered_p_values[altered_p_values['P-Value'] < 0.05]
num_plots = len(significant_p_values)
rows = (num_plots + 2) // 3 
cols = min(3, num_plots)

plt.figure(figsize=(15, 5*rows))

for i, (_, row) in enumerate(significant_p_values.iterrows()):
    college = row['College']
    college_year = row['College Year']
    job_year = row['Job Year']
    area = row['Area']
    p_value = row['P-Value']
    
    # Get the matching data from combined DataFrame
    specific_df = combined[
        (combined['College'] == college) & 
        (combined['College Year'] == college_year) & 
        (combined['Area'] == area) & 
        (combined['Job Year'] == job_year)
    ]
    
    if not specific_df.empty:
        # Calculate Spearman correlation
        correlation, _ = spearmanr(specific_df['Proportions'], specific_df['Bachelors'])
        
        plt.subplot(rows, cols, i+1)
        plt.scatter(specific_df['Proportions'], specific_df['Bachelors'], alpha=0.6)
        plt.xlabel('Proportions')
        plt.ylabel('Bachelors')
        plt.title(f'{college} ({area}:{college_year}-{job_year})\np={p_value:.3f}, r={correlation:.3f}')
        plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis:
#
# Numerous paired T-tests were conducted to analyze the proportions of the job market across major fields and degrees conferred by major fields. Since that a large number of tests were performed, we initially planned to use Bonferroni-Holm correction to ensure statistical informational accuracy and reliability; however, we had no significant p-values so this step wasn't needed. The p-values above for all selected colleges exceeded the statistical alpha value of 0.05, indicating a lack of statistical significance with our lowest p-value being 0.854725 for Colgate College and its local area Utica-Rome, NY.
#
# Furthermore we conducted another test on the data where all values within the proportion or bachelor’s field that contained a 0 were dropped from the data frame. This resulted in several p-values falling below the statistical alpha value of 0.05 which indicates statistical significance. However, the specific area and year in which these extreme values were generated, occurred for UCSD and its local area San Diego-Carlsbad from the years 2014-2017. The data for this year was differently classified compared to other areas and universities as UCSD reported only about 5 major categories, with everyone else falling into 'other'. Since no jobs were classified to the 'other' major field, only two non-zero data pairs remained, resulting in extremely low p-values and a Spearman correlation coefficent of 1. Given the inconsistencies and potential for any other possible systematic errors, the p-values generated from these years can be disregarded.
#
# As a result, we fail to reject the null hypothesis, which states that there is no statistical correlation between national job market trends and selection of majors by undergraduate students.
#
# Therefore, we cannot confidently conclude that there exists any significant correlation between the selections of majors at universities and the employment opportunities initiated from national job market trends.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# The data we’ve chosen to look at for our research proposal was extracted from public datasets published by the Bureau of Labor Statistics database as well as the common dataset from institutional research at UCSD. Since both of the provided datasets are public, we have permission to utilize this data for our research analysis which ensures that there should be no privacy concerns with our dataset as we are not analyzing specific individual students within our analysis. Furthermore, scraping information or data from these public statistical sets indicates that our proposal prevents targeted harm towards any individual industry’s or college’s reputation.
#
# Since we are retrieving data from many different public datasets, there is a lower possibility of any major potential biases arising from our data. However, since our research primarily focuses on the top majors from each of the universities that were selected beforehand, opportunities for ranking and selection bias may emerge. The bias arising from the top selected major rankings can be overcome by drawing information out from diverse sources which reduces dependency on any specific dataset. We are also focusing specifically on undergraduate graduation rates, which might not reflect people who only attend community college without transferring to a 4-year institution, trade schools, or any other form of schooling, since they would also be entering the job market. The best way to address this is to specify that our findings are specifically for 4-year undergraduate students and at the specific colleges we select, since the selection may not be completely random.
#
# The schools that we selected were chosen through pretty extensive research, as we wanted an accurate representation from public/private universities, urban/rural universities, and STEM/Humanities universities. We thus chose 8 different universities, and we listed out the reasonings behind them in the spreadsheet linked in our Dataset section. Overall, our main bias here was caused by limited field knowledge, as well as the fact that we wanted to include UCSD since we all go to school there. Again, we handle this bias in our selection of data by being transparent about our reasoning and not generalizing our results to areas they wouldn't apply to.
#
# Another source of bias present in our work is because of our use of OpenAI for classification of job to major field, as well as condensing some of the major fields. For example, the prompt we gave OpenAI was to essentially act as a college counselor and recommend a major for a student who was seeking a certain job; OpenAI would never classify any job as "liberal arts" or "interdisciplinary studies", when there would be students graduating with these majors. As a result, we were forced to combine some major groups together in a manner that we thought would be similar to OpenAI, and this definitely introduced some personal bias as we are not professional college counselors. Additionally, because we used OpenAI, the way the jobs were classified into majors is not at all transparent, because we have no way of accessing why OpenAI made the classifications it did. While it would have been more ethical to train our own classifier, this would have been much less feasible, and so we handle this ethical concern by making it very transparent that we used OpenAI to classify occupations to major fields.

# %% [markdown]
# # Discussion and Conclusion
#
# The main focus of this project was to determine whether or not national or local job market trends (measured by the number of jobs across the nation and in certain metropolitan/non-metropolitan areas) had any influence on undergraduate major selection from pre-selected universities across the nation. More specifically, we wanted to analyze which market had a more significant impact and which years prior to graduation had the most influence on major choice. We attempted to accomplish this by examining the relationship between employment and major distributions from 2014 to 2023.  We explored data of different datasets, provided by the Bureau of Labor Statistics, by metropolitan/non-metropolitan area from the years 2006 to 2023 as well as the public common data sets from the universities. Our overall results demonstrated that there was no statistically significant correlation between major selection and the national or local job market trends from 2014-2023.
#
# Examining the EDA, we determined that local and national market trends were extremely similar to one another but generally had moderate to little impact on the major selection of undergraduate students. Out of the eight metropolitan/non-metropolitan areas we observed, the local market often aligned with the national market trends with Business and Construction/Trades often having the highest employment proportion of demand. The major distributions on the other hand, had no specific major that was generally the highest and seemed to have had no influence from the national/local market demands.
#
# Following the EDA we conducted several paired T-Tests and found that we were unable to conclude that there exists any significant correlation between the selections of majors at universities and the employment opportunities generated from national job market trends. Out of the eight colleges that we analyzed, UCSD demonstrated that there may indeed be a positive correlation between national or local job market trends and the choices of undergraduate majors. However, these statistics alone are not enough evidence to confidently prove that major selection at universities are influenced by job market demands.
#
# The biggest limitation that our study encountered was data inconsistencies for the common data sets provided by the universities. Particularly, UCSD had misaligned major distributions from 2014-2017 as there was an “other” category that resulted in possible potential systematic errors when calculating the p-value for our paired t-tests. The p-values for this data were the only values that depicted any statistical significance which may lead to misinterpretations of the data. Furthermore, the employment data included occupations (e.g. Construction/Trades) that do not necessarily require an undergraduate degree which could lead to bias as the influence from national and local market demands to undergraduate major selection may not be as apparent.
#
# Overall, our study and work provides insight on the current state of national market demands and any effect it may have on major selections at universities. Previous analyses have determined that students are more likely to select their majors based on salaries but there have been no previous studies on how employment rates and major rates are correlated. Our project illustrates that although we concluded that there was no correlation between national and local job market trends and the selection of undergraduate majors from 2014 to 2023, we determined this from a selection of only eight colleges within the United States of America with their respective metropolitan/non-metropolitan areas. The study suggests that further research could be conducted internationally to expand on these findings. Although our study had some limitations, hopefully our study was able to provide some insightful information on the current economy and undergraduate major selection.
#
#
# # Team Contributions
#
# Michael He:
# - Data gathering
# - Data cleaning
# - Statistical tests
#
# Sarah Li:
# - EDA analysis
# - Ethics
# - Hypothesis + research question
#
# Dhiren Patel:
# - EDA analysis
# - Video Presentation
# - Hypothesis + research question
#
# Felicia Zhang:
# - Ethics
# - Statistical analysis
# - Writeups
